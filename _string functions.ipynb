# %%
name="kavitha"
print(name)
# Out:
# kavitha

# %%
name="sruthi"
email="sruthi345@gmail.com"
print(name,email)
# Out:
# sruthi sruthi345@gmail.com

# %% [markdown]
# city="pune"
# print(city)

# %%
city="pune"
print(city)
# Out:
# pune

# %%
city="pune"
print(city[3])
# Out:
# e

# %%
name="kavitha"
print(len(name))
# Out:
# 7

# %%
print("hello"*3)
# Out:
# hellohellohello

# %%
name="kavitha"
print(name.upper())
# Out:
# KAVITHA

# %%
s="I like Java"
print(s.replace("Java","python"))
# Out:
# I like python

# %%
name=input("enter the name:")
print("welcome",name)
# Out:
# enter the name: sruthi
# welcome sruthi

# %%
s="sreeja"
print(s[::-1])
# Out:
# ajeers

# %%
name="sruthi"
def greet ():
    print("hello",name)
greet()
# Out:
# hello sruthi
