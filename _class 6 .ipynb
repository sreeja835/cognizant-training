# %%
class Car:
    colour="red"
    brand="bmw"
    speed=120
print(Car.colour)
print(Car.brand)
# Out:
# red
# bmw

# %%
class Student:
    def __init__(self,name,age):
        self.name=name
        self.age=age

s1=Student("kavitha",32)
print(s1.name)
print(s1.age)
# Out:
# kavitha
# 32
